# %% [markdown]
# # Model

# %% [markdown]
# ## Load data

# %%
import pandas as pd 
import numpy as np 

df=pd.read_csv(fr'..\data\cleaned_data_08_2025.csv')

display(df.head())
# Out:
#    index  propertyCode     price  log_price              municipality  \
# 0      0     108933600  300000.0  12.611541    Esplugues de Llobregat
# 1      1     108932312  650000.0  13.384729  Santa Perpètua de Mogoda
# 2      2     108932560  570000.0  13.253393             Pineda de Mar
# 3      3     108933084  390600.0  12.875442                   Cabrils
# 4      4     108933074  250000.0  12.429220                  Masquefa
#
#   propertyType   size    cat_size  rooms  bathrooms floor_grouped  hasLift  \
# 0         flat   78.0     Mediana      4          1           3-4        1
# 1       chalet  243.0  Muy Grande      4          3             0        0
# 2       duplex  208.0  Muy Grande      4          3            5+        1
# 3       chalet  166.0  Muy Grande      3          2             0        0
# 4       chalet  212.0  Muy Grande      4          2             0        0
#
#     latitude  longitude
# 0  41.370454   2.083978
# 1  41.525747   2.192719
# ...

# %%
display(df['municipality'].value_counts())
# Out:
# municipality
# Barcelona                      1440
# Hospitalet de Llobregat         286
# Sabadell                        265
# Terrassa                        240
# Badalona                        204
#                                ...
# Sant esteve de Palautordera       1
# Jorba                             1
# Collsuspina                       1
# Artés                             1
# Pacs del Penedès                  1
# Name: count, Length: 204, dtype: int64

# %%
import geopandas as gpd
gdf = gpd.read_file(fr"..\data\comarques-barcelona.geojson")
print(gdf.columns)

for i in gdf.columns:
    print(f'\nColumn: {i}')
    print(gdf[i].unique())
# Out:
# Index(['cap_comar', 'comarca', 'nom_comar', 'geometry'], dtype='object')
#
# Column: cap_comar
# ['Vilafranca del Penedès' 'Igualada' 'Manresa' 'Sant Feliu de Llobregat'
#  'Barcelona' 'Berga' 'Vilanova i la Geltrú' 'Mataró' 'Vic'
#  'Sabadell / Terrassa' 'Granollers']
#
# Column: comarca
# ['03' '06' '07' '11' '13' '14' '17' '21' '24' '40' '41']
#
# Column: nom_comar
# ['Alt Penedès' 'Anoia' 'Bages' 'Baix Llobregat' 'Barcelonès' 'Berguedà'
#  'Garraf' 'Maresme' 'Osona' 'Vallès Occidental' 'Vallès Oriental']
#
# Column: geometry
# <GeometryArray>
# [<MULTIPOLYGON (((1.495 41.436, 1.502 41.429, 1.517 41.437, 1.534 41.44, 1.53...>,
#  <MULTIPOLYGON (((1.471 41.801, 1.473 41.783, 1.461 41.777, 1.467 41.771, 1.4...>,
#  <MULTIPOLYGON (((1.648 41.957, 1.664 41.963, 1.674 41.948, 1.686 41.938, 1.7...>,
#  <MULTIPOLYGON (((1.813 41.604, 1.825 41.594, 1.832 41.591, 1.863 41.592, 1.8...>,
#  <MULTIPOLYGON (((2.059 41.435, 2.067 41.43, 2.071 41.419, 2.057 41.418, 2.05...>,
# ...
